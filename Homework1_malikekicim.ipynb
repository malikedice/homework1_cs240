# %%
from __future__ import print_function, division;

import nsfg #Add the data what will I use
import thinkstats2
import thinkplot

# %%
pres = nsfg.ReadFemResp()
pres.columns #prepare the coloum
# Out:
# Index([u'caseid', u'rscrinf', u'rdormres', u'rostscrn', u'rscreenhisp',
#        u'rscreenrace', u'age_a', u'age_r', u'cmbirth', u'agescrn',
#        ...
#        u'pubassis_i', u'basewgt', u'adj_mod_basewgt', u'finalwgt', u'secu_r',
#        u'sest', u'cmintvw', u'cmlstyr', u'screentime', u'intvlngth'],
#       dtype='object', length=3087)

# %%
pres.outcome.value_counts().sort_index() #index
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-7a7f13759e8b> in <module>()
# ----> 1 pres.outcome.value_counts().sort_index() #index
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'outcome'

# %%
pres.head(20) # show the first 20
# Out:
#     caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0        1         1        NaN        NaN       NaN       NaN       6.0
# 1        1         2        NaN        NaN       NaN       NaN       6.0
# 2        2         1        NaN        NaN       NaN       NaN       5.0
# 3        2         2        NaN        NaN       NaN       NaN       6.0
# 4        2         3        NaN        NaN       NaN       NaN       6.0
# 5        6         1        NaN        NaN       NaN       NaN       6.0
# 6        6         2        NaN        NaN       NaN       NaN       6.0
# 7        6         3        NaN        NaN       NaN       NaN       6.0
# 8        7         1        NaN        NaN       NaN       NaN       5.0
# 9        7         2        NaN        NaN       NaN       NaN       5.0
# 10      12         1        NaN        NaN       NaN       NaN       5.0
# 11      14         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
pres.tail(30) # show the last 30
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 13563   12547         2        NaN        NaN       NaN       NaN       6.0
# 13564   12547         3        NaN        NaN       NaN       NaN       6.0
# 13565   12550         1        NaN        NaN       NaN       NaN       6.0
# 13566   12551         1        NaN        NaN       NaN       NaN       5.0
# 13567   12554         1        NaN        NaN       NaN       NaN       3.0
# 13568   12554         2        NaN        NaN       NaN       NaN       4.0
# 13569   12556         1        NaN        NaN       NaN       NaN       6.0
# 13570   12556         2        NaN        NaN       NaN       NaN       6.0
# 13571   12556         3        NaN        NaN       NaN       NaN       6.0
# 13572   12556         4        NaN        NaN       NaN       NaN       6.0
# 13573   12561         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
columnsN = len(pres.columns)

# %%
rowsN = len(pres)

# %%
print("there are %d rows and %d columns" %(rowsN,columnsN)) #print a sentences
# Out:
# there are 7643 rows and 3087 columns

# %%
pres["agescrn"]  #Select the "agescrn" column from resp and print the value counts. ...
# Out:
# 0        44
# 1        44
# 2        20
# 3        20
# 4        20
# 5        40
# 6        40
# 7        40
# 8        39
# 9        39
# 10       40
# 11       36
# 12       36
# 13       36
# 14       32
# 15       32
# 16       32
# 17       42
# 18       42
# 19       35
# 20       35
# 21       42
# 22       42
# 23       35
# 24       35
# 25       35
# 26       39
# 27       44
# 28       44
# 29       44
#          ..
# 13563    32
# 13564    32
# 13565    20
# 13566    38
# 13567    32
# 13568    32
# 13569    42
# 13570    42
# 13571    42
# 13572    42
# 13573    44
# 13574    44
# 13575    33
# 13576    34
# 13577    34
# 13578    27
# 13579    27
# 13580    35
# 13581    35
# 13582    35
# 13583    31
# 13584    31
# 13585    37
# 13586    37
# 13587    37
# 13588    37
# 13589    37
# 13590    37
# 13591    37
# 13592    37
# Name: agescrn, Length: 13593, dtype: int64

# %%
min(pres["agescrn"]) #en genc who are 25
# Out:
# 15

# %%
max(pres["agescrn"]) #en yaslı who are under 25
# Out:
# 44

# %%
pres["pregnum"][pres.caseid==2298]  #average of the Pregnancies 2
# Out:
# 0    4
# Name: pregnum, dtype: int64

# %%
pres[pres["agescrn"] <= 25]["pregnum"].mean()
# Out:
# 2.7583756345177664

# %%
pres.agescrn.value_counts()[max(pres["agescrn"])]
# Out:
# 589

# %%
mean = 0
for i in range(len(pres)):
    if pres.agescrn[i] == max(pres["agescrn"]):
        mean += preg.pregnum[i]
print(mean/pres.agescrn.value_counts()[max(pres["agescrn"])])
# Out:
# 3.7130730050933787

# %%
list_fmarno = []
total = 0
for i in pres["fmarno"]:
    list_fmarno.append(i)
    
hist2 = thinkstats2.Hist(sorted(list_fmarno))
print("Value\tLabel\tTotal")
for i in hist2:
    if(i == 0):
        print(str(i) + "\tnever been married\t" + str(hist2[i]))
    elif(i == 1):
        print(str(i) + "\t1 Time\t\t\t" + str(hist2[i]))
    elif(i == 2):
        print(str(i) + "\t2 Times\t\t\t" + str(hist2[i]))
    elif(i == 3):
        print(str(i) + "\t3 Times\t\t\t" + str(hist2[i]))
    elif(i == 4):
        print(str(i) + "\t4 Times\t\t\t" + str(hist2[i]))
    else:
        print(str(i) + "\t5 Times\t\t\t" + str(hist2[i]))
    total += hist2[i]

print("\ttotal\t\t\t" + str(total))
thinkplot.Hist(hist2)
thinkplot.Show(xlabel='data of value', ylabel='frequency')
# Out:
# Value	Label	Total
# 0	never been married	3517
# 1	1 Time			3436
# 2	2 Times			582
# 3	3 Times			90
# 4	4 Times			15
# 5	5 Times			3
# 	total			7643
# No handlers could be found for logger "matplotlib.legend"

# %%
neverMarried = pres[pres.fmarno == 0]
married = pres[pres.fmarno >= 1]
first = thinkstats2.Hist(neverMarried.totincr, label="Never Married")
second = thinkstats2.Hist(married.totincr, label="Married")

width = 0.25
#thinkplot.PrePlot(2)
thinkplot.Hist(first, align='right', width=width)
thinkplot.Hist(second, align='left', width=width)
thinkplot.Show(xlabel='weeks', ylabel='Count')
